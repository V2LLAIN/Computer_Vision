# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
# Out:
# 2023-04-03 11:02:41.894210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 11:02:42.020505: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 11:02:42.047509: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # U-Net

# %%
from tensorflow import keras

img_size=(224, 224);  n_class = 200;  batch_size=32

def U_Net(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3, ))
    
    # U-Net의 DownSampling
    x = Conv2D(32, 3, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # shortcut connection을 위해
    previous_block_activation = x
    
    for filters in [64, 128, 256]:
        x = Activation('relu')(x)
        x = SeparableConv2D(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = SeparableConv2D(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)
        x = MaxPooling2D(3, strides=2, padding='same')(x)
        
        residual = Conv2D(filters, 1, strides=2, padding='same')(previous_block_activation)
        x = add([x, residual])
        previous_block_activation = x
        
        
        
    # U-Net의 UpSampling
    for filters in [256, 128, 64, 32]:
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)
        x = Activation('relu')(x)
        x = Conv2DTranspose(filters, 3, padding='same')(x)
        x = BatchNormalization()(x)
        x = UpSampling2D(2)(x)
        
        residual = UpSampling2D(2)(previous_block_activation)
        residual = Conv2D(filters, 1, padding='same')(residual)
        x = add([x, residual])
        previous_block_activation = x
        
        
        
        
    outputs = Conv2D(num_classes, 3, activation='softmax', padding='same')(x)
    model = Model(inputs, outputs)
    return model

model = U_Net(img_size, n_class)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_515 (Conv2D)            (None, 112, 112, 32  896         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_432 (Batch  (None, 112, 112, 32  128        ['conv2d_515[0][0]']
#  Normalization)                 )
#
#  activation_264 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_432[0][0]']
#                                 )
#
#  activation_265 (Activation)    (None, 112, 112, 32  0           ['activation_264[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 112, 112, 64  2400       ['activation_265[0][0]']
#  v2D)                           )
#
#  batch_normalization_433 (Batch  (None, 112, 112, 64  256        ['separable_conv2d[0][0]']
#  Normalization)                 )
#
#  activation_266 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_433[0][0]']
#                                 )
#
#  separable_conv2d_1 (SeparableC  (None, 112, 112, 64  4736       ['activation_266[0][0]']
#  onv2D)                         )
#
#  batch_normalization_434 (Batch  (None, 112, 112, 64  256        ['separable_conv2d_1[0][0]']
#  Normalization)                 )
#
#  max_pooling2d_24 (MaxPooling2D  (None, 56, 56, 64)  0           ['batch_normalization_434[0][0]']
#  )
#
#  conv2d_516 (Conv2D)            (None, 56, 56, 64)   2112        ['activation_264[0][0]']
#
#  add_57 (Add)                   (None, 56, 56, 64)   0           ['max_pooling2d_24[0][0]',
#                                                                   'conv2d_516[0][0]']
#
#  activation_267 (Activation)    (None, 56, 56, 64)   0           ['add_57[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 56, 56, 128)  8896       ['activation_267[0][0]']
#  onv2D)
#
#  batch_normalization_435 (Batch  (None, 56, 56, 128)  512        ['separable_conv2d_2[0][0]']
#  Normalization)
#
#  activation_268 (Activation)    (None, 56, 56, 128)  0           ['batch_normalization_435[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 56, 56, 128)  17664      ['activation_268[0][0]']
#  onv2D)
#
#  batch_normalization_436 (Batch  (None, 56, 56, 128)  512        ['separable_conv2d_3[0][0]']
#  Normalization)
#
#  max_pooling2d_25 (MaxPooling2D  (None, 28, 28, 128)  0          ['batch_normalization_436[0][0]']
#  )
#
#  conv2d_517 (Conv2D)            (None, 28, 28, 128)  8320        ['add_57[0][0]']
#
#  add_58 (Add)                   (None, 28, 28, 128)  0           ['max_pooling2d_25[0][0]',
#                                                                   'conv2d_517[0][0]']
#
#  activation_269 (Activation)    (None, 28, 28, 128)  0           ['add_58[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 28, 28, 256)  34176      ['activation_269[0][0]']
#  onv2D)
#
#  batch_normalization_437 (Batch  (None, 28, 28, 256)  1024       ['separable_conv2d_4[0][0]']
#  Normalization)
#
#  activation_270 (Activation)    (None, 28, 28, 256)  0           ['batch_normalization_437[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 28, 28, 256)  68096      ['activation_270[0][0]']
#  onv2D)
#
#  batch_normalization_438 (Batch  (None, 28, 28, 256)  1024       ['separable_conv2d_5[0][0]']
#  Normalization)
#
#  max_pooling2d_26 (MaxPooling2D  (None, 14, 14, 256)  0          ['batch_normalization_438[0][0]']
#  )
#
#  conv2d_518 (Conv2D)            (None, 14, 14, 256)  33024       ['add_58[0][0]']
#
#  add_59 (Add)                   (None, 14, 14, 256)  0           ['max_pooling2d_26[0][0]',
#                                                                   'conv2d_518[0][0]']
#
#  activation_271 (Activation)    (None, 14, 14, 256)  0           ['add_59[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 14, 14, 256)  590080     ['activation_271[0][0]']
#  ose)
#
#  batch_normalization_439 (Batch  (None, 14, 14, 256)  1024       ['conv2d_transpose[0][0]']
#  Normalization)
#
#  activation_272 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_439[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 14, 14, 256)  590080     ['activation_272[0][0]']
#  spose)
#
#  batch_normalization_440 (Batch  (None, 14, 14, 256)  1024       ['conv2d_transpose_1[0][0]']
#  Normalization)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 28, 28, 256)  0          ['add_59[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 28, 28, 256)  0           ['batch_normalization_440[0][0]']
#
#  conv2d_519 (Conv2D)            (None, 28, 28, 256)  65792       ['up_sampling2d_1[0][0]']
#
#  add_60 (Add)                   (None, 28, 28, 256)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_519[0][0]']
#
#  activation_273 (Activation)    (None, 28, 28, 256)  0           ['add_60[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 28, 28, 128)  295040     ['activation_273[0][0]']
#  spose)
#
#  batch_normalization_441 (Batch  (None, 28, 28, 128)  512        ['conv2d_transpose_2[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_441[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 28, 28, 128)  147584     ['activation_274[0][0]']
#  spose)
#
#  batch_normalization_442 (Batch  (None, 28, 28, 128)  512        ['conv2d_transpose_3[0][0]']
#  Normalization)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0          ['add_60[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 56, 56, 128)  0          ['batch_normalization_442[0][0]']
#
#  conv2d_520 (Conv2D)            (None, 56, 56, 128)  32896       ['up_sampling2d_3[0][0]']
#
#  add_61 (Add)                   (None, 56, 56, 128)  0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_520[0][0]']
#
#  activation_275 (Activation)    (None, 56, 56, 128)  0           ['add_61[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 56, 56, 64)  73792       ['activation_275[0][0]']
#  spose)
#
#  batch_normalization_443 (Batch  (None, 56, 56, 64)  256         ['conv2d_transpose_4[0][0]']
#  Normalization)
#
#  activation_276 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_443[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 56, 56, 64)  36928       ['activation_276[0][0]']
#  spose)
#
#  batch_normalization_444 (Batch  (None, 56, 56, 64)  256         ['conv2d_transpose_5[0][0]']
#  Normalization)
#
#  up_sampling2d_5 (UpSampling2D)  (None, 112, 112, 12  0          ['add_61[0][0]']
#                                 8)
#
#  up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 64  0          ['batch_normalization_444[0][0]']
#                                 )
#
#  conv2d_521 (Conv2D)            (None, 112, 112, 64  8256        ['up_sampling2d_5[0][0]']
#                                 )
#
#  add_62 (Add)                   (None, 112, 112, 64  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_521[0][0]']
#
#  activation_277 (Activation)    (None, 112, 112, 64  0           ['add_62[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 112, 112, 32  18464      ['activation_277[0][0]']
#  spose)                         )
#
#  batch_normalization_445 (Batch  (None, 112, 112, 32  128        ['conv2d_transpose_6[0][0]']
#  Normalization)                 )
#
#  activation_278 (Activation)    (None, 112, 112, 32  0           ['batch_normalization_445[0][0]']
#                                 )
#
#  conv2d_transpose_7 (Conv2DTran  (None, 112, 112, 32  9248       ['activation_278[0][0]']
#  spose)                         )
#
#  batch_normalization_446 (Batch  (None, 112, 112, 32  128        ['conv2d_transpose_7[0][0]']
#  Normalization)                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 224, 224, 64  0          ['add_62[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 224, 224, 32  0          ['batch_normalization_446[0][0]']
#                                 )
#
#  conv2d_522 (Conv2D)            (None, 224, 224, 32  2080        ['up_sampling2d_7[0][0]']
#                                 )
#
#  add_63 (Add)                   (None, 224, 224, 32  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'conv2d_522[0][0]']
#
#  conv2d_523 (Conv2D)            (None, 224, 224, 20  57800       ['add_63[0][0]']
#                                 0)
#
# ==================================================================================================
# Total params: 2,115,912
# Trainable params: 2,112,136
# Non-trainable params: 3,776
# __________________________________________________________________________________________________
