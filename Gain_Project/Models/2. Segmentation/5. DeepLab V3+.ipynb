# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
# Out:
# 2023-04-03 11:02:41.894210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 11:02:42.020505: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 11:02:42.047509: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # DeepLab V3+

# %% [markdown]
# ## Encoder 생성
# - ResNet50을 기반모델로 생성

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

inputs = keras.layers.Input(shape=input_shape)

def encoder(inputs):
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=inputs)

    # ResNet50에서의 layer 이름을 기반으로, 해당 layer까지의 output tensor를 저장
    x1 = base_model.get_layer('conv4_block6_out').output
    x2 = base_model.get_layer('conv3_block4_out').output
    x3 = base_model.get_layer('conv2_block3_out').output
    x4 = base_model.get_layer('conv1_relu').output

    return x1, x2, x3, x4

x1, x2, x3, x4 = encoder(inputs)

# %% [markdown]
# ### ASPP(Atrous Spatial Pyramid Pooling)
# ##### Atrous convolution는 dilated convolution과 거의 비슷하다.
# - Dilated Convolution은 필터에 구멍을 뚫어서 연산량을 줄이는 방식으로 연산을 수행(https://github.com/vdumoulin/conv_arithmetic/blob/master/gif/dilation.gif)
# - Atrous Convolution은 필터의 크기를 확장시키고 zero padding을 추가하여 연산량을 줄이는 방식으로 연산을 수행한다.

# %%
def aspp(x, output_stride):
    # global average pooling
    pool_size = (tf.shape(x)[1], tf.shape(x)[2])
    x = layers.AveragePooling2D(pool_size=pool_size)(x)
    x = layers.Conv2D(256, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # 1x1 convolution
    b = layers.Conv2D(256, 1, dilation_rate=1, padding='same', use_bias=False)(x)
    b = layers.BatchNormalization()(b)
    b = layers.ReLU()(b)

    # 3x3 convolutions with different dilation rates
    r1 = layers.Conv2D(256, 3, dilation_rate=6, padding='same', use_bias=False)(x)
    r1 = layers.BatchNormalization()(r1)
    r1 = layers.ReLU()(r1)

    r2 = layers.Conv2D(256, 3, dilation_rate=12, padding='same', use_bias=False)(x)
    r2 = layers.BatchNormalization()(r2)
    r2 = layers.ReLU()(r2)

    # Block 3
    r3 = layers.SeparableConv2D(256, (3, 3), padding='same', name='block3_sepconv1')(r2)
    r3 = layers.BatchNormalization(name='block3_sepconv1_bn')(r3)
    r3 = layers.ReLU(name='block3_sepconv2_act')(r3)
    r3 = layers.SeparableConv2D(256, (3, 3), padding='same', name='block3_sepconv2')(r3)
    r3 = layers.BatchNormalization(name='block3_sepconv2_bn')(r3)
    r3 = layers.ReLU(name='block3_sepconv3_act')(r3)
    r3 = layers.SeparableConv2D(256, (3, 3), padding='same', name='block3_sepconv3')(r3)
    r3 = layers.BatchNormalization(name='block3_sepconv3_bn')(r3)
    r3 = layers.ReLU()(r3)

    # Block 4
    x = layers.Conv2D(4 * 256, (1, 1), padding='same', strides=(2, 2),
    name='block4_conv1')(r3)
    x = layers.BatchNormalization(name='block4_conv1_bn')(x)

    prev_res = layers.Conv2D(4 * 256, (1, 1), padding='same', strides=(2, 2),
    name='block2_conv1')(r1)
    prev_res = layers.BatchNormalization(name='block2_conv1_bn')(prev_res)
    x = layers.Add(name='block4_add')([x, prev_res])

    # Block 5
    x = layers.SeparableConv2D(512, (3, 3), padding='same', name='block5_sepconv1')(x)
    x = layers.BatchNormalization(name='block5_sepconv1_bn')(x)
    x = layers.ReLU(name='block5_sepconv2_act')(x)
    x = layers.SeparableConv2D(512, (3, 3), padding='same', name='block5_sepconv2')(x)
    x = layers.BatchNormalization(name='block5_sepconv2_bn')(x)
    x = layers.ReLU(name='block5_sepconv3_act')(x)
    x = layers.SeparableConv2D(512, (3, 3), padding='same', name='block5_sepconv3')(x)
    x = layers.BatchNormalization(name='block5_sepconv3_bn')(x)
    x = layers.ReLU()(x)

    # Block 6
    x = layers.AveragePooling2D((7, 7), name='avg_pool')(x)
    x = layers.Conv2D(classes, (1, 1), padding='same', name='prediction')(x)
    x = layers.Activation('softmax', name='softmax')(x)


    model = Model(img_input, x, name='deeplabv3plus')

    return model

# %%
input_shape = (224, 224, 3); num_classes = 10

# 모델 생성
model = DeConvNet(input_shape, num_classes)

model.summary()
# Out:
# Model: "model_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 224, 224, 3)]     0
#
#  conv2d_572 (Conv2D)         (None, 224, 224, 64)      1792
#
#  batch_normalization_500 (Ba  (None, 224, 224, 64)     256
#  tchNormalization)
#
#  activation_322 (Activation)  (None, 224, 224, 64)     0
#
#  conv2d_573 (Conv2D)         (None, 224, 224, 64)      36928
#
#  batch_normalization_501 (Ba  (None, 224, 224, 64)     256
#  tchNormalization)
#
#  activation_323 (Activation)  (None, 224, 224, 64)     0
#
#  max_pooling2d_42 (MaxPoolin  (None, 112, 112, 64)     0
#  g2D)
#
#  conv2d_574 (Conv2D)         (None, 112, 112, 128)     73856
#
#  batch_normalization_502 (Ba  (None, 112, 112, 128)    512
#  tchNormalization)
#
#  activation_324 (Activation)  (None, 112, 112, 128)    0
#
#  conv2d_575 (Conv2D)         (None, 112, 112, 128)     147584
#
#  batch_normalization_503 (Ba  (None, 112, 112, 128)    512
#  tchNormalization)
#
#  activation_325 (Activation)  (None, 112, 112, 128)    0
#
#  max_pooling2d_43 (MaxPoolin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_576 (Conv2D)         (None, 56, 56, 256)       295168
#
#  batch_normalization_504 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_326 (Activation)  (None, 56, 56, 256)      0
#
#  conv2d_577 (Conv2D)         (None, 56, 56, 256)       590080
#
#  batch_normalization_505 (Ba  (None, 56, 56, 256)      1024
#  tchNormalization)
#
#  activation_327 (Activation)  (None, 56, 56, 256)      0
#
#  max_pooling2d_44 (MaxPoolin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_578 (Conv2D)         (None, 28, 28, 512)       1180160
#
#  batch_normalization_506 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_328 (Activation)  (None, 28, 28, 512)      0
#
#  conv2d_579 (Conv2D)         (None, 28, 28, 512)       2359808
#
#  batch_normalization_507 (Ba  (None, 28, 28, 512)      2048
#  tchNormalization)
#
#  activation_329 (Activation)  (None, 28, 28, 512)      0
#
#  max_pooling2d_45 (MaxPoolin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_580 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  batch_normalization_508 (Ba  (None, 14, 14, 512)      2048
#  tchNormalization)
#
#  activation_330 (Activation)  (None, 14, 14, 512)      0
#
#  conv2d_581 (Conv2D)         (None, 14, 14, 512)       2359808
#
#  batch_normalization_509 (Ba  (None, 14, 14, 512)      2048
#  tchNormalization)
#
#  activation_331 (Activation)  (None, 14, 14, 512)      0
#
#  max_pooling2d_46 (MaxPoolin  (None, 7, 7, 512)        0
#  g2D)
#
#  conv2d_transpose_19 (Conv2D  (None, 7, 7, 512)        2359808
#  Transpose)
#
#  batch_normalization_510 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_332 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_transpose_20 (Conv2D  (None, 7, 7, 512)        2359808
#  Transpose)
#
#  batch_normalization_511 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_333 (Activation)  (None, 7, 7, 512)        0
#
#  conv2d_transpose_21 (Conv2D  (None, 7, 7, 512)        2359808
#  Transpose)
#
#  batch_normalization_512 (Ba  (None, 7, 7, 512)        2048
#  tchNormalization)
#
#  activation_334 (Activation)  (None, 7, 7, 512)        0
#
#  up_sampling2d_15 (UpSamplin  (None, 14, 14, 512)      0
#  g2D)
#
#  conv2d_transpose_22 (Conv2D  (None, 14, 14, 256)      1179904
#  Transpose)
#
#  batch_normalization_513 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_335 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_transpose_23 (Conv2D  (None, 14, 14, 256)      590080
#  Transpose)
#
#  batch_normalization_514 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_336 (Activation)  (None, 14, 14, 256)      0
#
#  conv2d_transpose_24 (Conv2D  (None, 14, 14, 256)      590080
#  Transpose)
#
#  batch_normalization_515 (Ba  (None, 14, 14, 256)      1024
#  tchNormalization)
#
#  activation_337 (Activation)  (None, 14, 14, 256)      0
#
#  up_sampling2d_16 (UpSamplin  (None, 28, 28, 256)      0
#  g2D)
#
#  conv2d_transpose_25 (Conv2D  (None, 28, 28, 128)      295040
#  Transpose)
#
#  batch_normalization_516 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_338 (Activation)  (None, 28, 28, 128)      0
#
#  conv2d_transpose_26 (Conv2D  (None, 28, 28, 128)      147584
#  Transpose)
#
#  batch_normalization_517 (Ba  (None, 28, 28, 128)      512
#  tchNormalization)
#
#  activation_339 (Activation)  (None, 28, 28, 128)      0
#
#  up_sampling2d_17 (UpSamplin  (None, 56, 56, 128)      0
#  g2D)
#
#  conv2d_transpose_27 (Conv2D  (None, 56, 56, 64)       73792
#  Transpose)
#
#  batch_normalization_518 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_340 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_transpose_28 (Conv2D  (None, 56, 56, 64)       36928
#  Transpose)
#
#  batch_normalization_519 (Ba  (None, 56, 56, 64)       256
#  tchNormalization)
#
#  activation_341 (Activation)  (None, 56, 56, 64)       0
#
#  conv2d_582 (Conv2D)         (None, 56, 56, 10)        650
#
#  activation_342 (Activation)  (None, 56, 56, 10)       0
#
# =================================================================
# Total params: 19,421,002
# Trainable params: 19,409,738
# Non-trainable params: 11,264
# _________________________________________________________________
