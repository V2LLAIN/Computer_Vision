# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
# Out:
# 2023-04-03 11:02:41.894210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 11:02:42.020505: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 11:02:42.047509: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # ResNet V2

# %%
def conv2d_bn(x, filters, kernel_size, strides=1, padding='same'):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding=padding)(x)
    x = BatchNormalization()(x)
    return x

def residual_block(x, filters, kernel_size, strides=1):
    shortcut = x
    x = conv2d_bn(x, filters, kernel_size, strides)
    x = ReLU()(x)
    x = conv2d_bn(x, filters, kernel_size, 1)
    if x.shape != shortcut.shape:
        shortcut = Conv2D(filters=filters,
                          kernel_size=1,
                          strides=strides,
                          padding='same')(shortcut)
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

def resnetv2(input_shape, num_classes, num_layers, use_bottleneck=False):
    num_blocks = (num_layers - 2) // 9
    filters = 16

    inputs = Input(shape=input_shape)

    x = conv2d_bn(inputs, filters, 3)

    for i in range(num_blocks):
        for j in range(3):
            strides = 1
            if j == 0:
                strides = 2
            x = residual_block(x, filters, 3, strides)
        filters *= 2

    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=x)

    return model

model = resnetv2(input_shape=(224,224,3),  num_classes=200, num_layers=20, use_bottleneck=True)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_236 (Conv2D)            (None, 224, 224, 16  448         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_155 (Batch  (None, 224, 224, 16  64         ['conv2d_236[0][0]']
#  Normalization)                 )
#
#  conv2d_237 (Conv2D)            (None, 112, 112, 16  2320        ['batch_normalization_155[0][0]']
#                                 )
#
#  batch_normalization_156 (Batch  (None, 112, 112, 16  64         ['conv2d_237[0][0]']
#  Normalization)                 )
#
#  re_lu_205 (ReLU)               (None, 112, 112, 16  0           ['batch_normalization_156[0][0]']
#                                 )
#
#  conv2d_238 (Conv2D)            (None, 112, 112, 16  2320        ['re_lu_205[0][0]']
#                                 )
#
#  batch_normalization_157 (Batch  (None, 112, 112, 16  64         ['conv2d_238[0][0]']
#  Normalization)                 )
#
#  conv2d_239 (Conv2D)            (None, 112, 112, 16  272         ['batch_normalization_155[0][0]']
#                                 )
#
#  add_51 (Add)                   (None, 112, 112, 16  0           ['batch_normalization_157[0][0]',
#                                 )                                 'conv2d_239[0][0]']
#
#  re_lu_206 (ReLU)               (None, 112, 112, 16  0           ['add_51[0][0]']
#                                 )
#
#  conv2d_240 (Conv2D)            (None, 112, 112, 16  2320        ['re_lu_206[0][0]']
#                                 )
#
#  batch_normalization_158 (Batch  (None, 112, 112, 16  64         ['conv2d_240[0][0]']
#  Normalization)                 )
#
#  re_lu_207 (ReLU)               (None, 112, 112, 16  0           ['batch_normalization_158[0][0]']
#                                 )
#
#  conv2d_241 (Conv2D)            (None, 112, 112, 16  2320        ['re_lu_207[0][0]']
#                                 )
#
#  batch_normalization_159 (Batch  (None, 112, 112, 16  64         ['conv2d_241[0][0]']
#  Normalization)                 )
#
#  add_52 (Add)                   (None, 112, 112, 16  0           ['batch_normalization_159[0][0]',
#                                 )                                 're_lu_206[0][0]']
#
#  re_lu_208 (ReLU)               (None, 112, 112, 16  0           ['add_52[0][0]']
#                                 )
#
#  conv2d_242 (Conv2D)            (None, 112, 112, 16  2320        ['re_lu_208[0][0]']
#                                 )
#
#  batch_normalization_160 (Batch  (None, 112, 112, 16  64         ['conv2d_242[0][0]']
#  Normalization)                 )
#
#  re_lu_209 (ReLU)               (None, 112, 112, 16  0           ['batch_normalization_160[0][0]']
#                                 )
#
#  conv2d_243 (Conv2D)            (None, 112, 112, 16  2320        ['re_lu_209[0][0]']
#                                 )
#
#  batch_normalization_161 (Batch  (None, 112, 112, 16  64         ['conv2d_243[0][0]']
#  Normalization)                 )
#
#  add_53 (Add)                   (None, 112, 112, 16  0           ['batch_normalization_161[0][0]',
#                                 )                                 're_lu_208[0][0]']
#
#  re_lu_210 (ReLU)               (None, 112, 112, 16  0           ['add_53[0][0]']
#                                 )
#
#  conv2d_244 (Conv2D)            (None, 56, 56, 32)   4640        ['re_lu_210[0][0]']
#
#  batch_normalization_162 (Batch  (None, 56, 56, 32)  128         ['conv2d_244[0][0]']
#  Normalization)
#
#  re_lu_211 (ReLU)               (None, 56, 56, 32)   0           ['batch_normalization_162[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 56, 56, 32)   9248        ['re_lu_211[0][0]']
#
#  batch_normalization_163 (Batch  (None, 56, 56, 32)  128         ['conv2d_245[0][0]']
#  Normalization)
#
#  conv2d_246 (Conv2D)            (None, 56, 56, 32)   544         ['re_lu_210[0][0]']
#
#  add_54 (Add)                   (None, 56, 56, 32)   0           ['batch_normalization_163[0][0]',
#                                                                   'conv2d_246[0][0]']
#
#  re_lu_212 (ReLU)               (None, 56, 56, 32)   0           ['add_54[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 56, 56, 32)   9248        ['re_lu_212[0][0]']
#
#  batch_normalization_164 (Batch  (None, 56, 56, 32)  128         ['conv2d_247[0][0]']
#  Normalization)
#
#  re_lu_213 (ReLU)               (None, 56, 56, 32)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 56, 56, 32)   9248        ['re_lu_213[0][0]']
#
#  batch_normalization_165 (Batch  (None, 56, 56, 32)  128         ['conv2d_248[0][0]']
#  Normalization)
#
#  add_55 (Add)                   (None, 56, 56, 32)   0           ['batch_normalization_165[0][0]',
#                                                                   're_lu_212[0][0]']
#
#  re_lu_214 (ReLU)               (None, 56, 56, 32)   0           ['add_55[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 56, 56, 32)   9248        ['re_lu_214[0][0]']
#
#  batch_normalization_166 (Batch  (None, 56, 56, 32)  128         ['conv2d_249[0][0]']
#  Normalization)
#
#  re_lu_215 (ReLU)               (None, 56, 56, 32)   0           ['batch_normalization_166[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 56, 56, 32)   9248        ['re_lu_215[0][0]']
#
#  batch_normalization_167 (Batch  (None, 56, 56, 32)  128         ['conv2d_250[0][0]']
#  Normalization)
#
#  add_56 (Add)                   (None, 56, 56, 32)   0           ['batch_normalization_167[0][0]',
#                                                                   're_lu_214[0][0]']
#
#  re_lu_216 (ReLU)               (None, 56, 56, 32)   0           ['add_56[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['re_lu_216[0][0]']
#  obalAveragePooling2D)
#
#  dense_11 (Dense)               (None, 200)          6600        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 73,880
# Trainable params: 73,272
# Non-trainable params: 608
# __________________________________________________________________________________________________
