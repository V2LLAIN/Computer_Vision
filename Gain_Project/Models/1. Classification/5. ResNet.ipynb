# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
# Out:
# 2023-04-03 11:02:41.894210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 11:02:42.020505: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 11:02:42.047509: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # ResNet

# %%
def conv_bn_relu(x, filters, kernel_size, strides=1, padding='same'):
    x = Conv2D(filters, kernel_size, strides=strides, padding=padding)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x

def identity_block(x, filters):
    shortcut = x
    x = conv_bn_relu(x, filters, 1)
    x = conv_bn_relu(x, filters, 3)
    x = conv_bn_relu(x, filters * 4, 1)
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

def projection_block(x, filters, strides):
    shortcut = conv_bn_relu(x, filters * 4, 1, strides)
    x = conv_bn_relu(x, filters, 1, strides)
    x = conv_bn_relu(x, filters, 3)
    x = conv_bn_relu(x, filters * 4, 1)
    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

def resnet(input_shape, num_classes, num_layers):
    if num_layers == 50:
        num_blocks = [3, 4, 6, 3]   
    elif num_layers == 101:
        num_blocks = [3, 4, 23, 3]   
    elif num_layers == 152:
        num_blocks = [3, 8, 36, 3]

    conv2_x, conv3_x, conv4_x, conv5_x = num_blocks

    inputs = Input(shape=input_shape)
    x = ZeroPadding2D(padding=(3, 3))(inputs)
    x = conv_bn_relu(x, 64, 7, strides=2)
    x = MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(x)

    x = projection_block(x, 64, strides=1)
    for _ in range(conv2_x - 1):
        x = identity_block(x, 64)

    x = projection_block(x, 128, strides=2)
    for _ in range(conv3_x - 1):
        x = identity_block(x, 128)

    x = projection_block(x, 256, strides=2)
    for _ in range(conv4_x - 1):
        x = identity_block(x, 256)

    x = projection_block(x, 512, strides=2)
    for _ in range(conv5_x - 1):
        x = identity_block(x, 512)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model

model = resnet(input_shape=(224,224,3),  num_classes=200, num_layers=152)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_4[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 115, 115, 64  9472        ['zero_padding2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 115, 115, 64  256        ['conv2d_78[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 115, 115, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d_21 (MaxPooling2D  (None, 58, 58, 64)  0           ['re_lu[0][0]']
#  )
#
#  conv2d_80 (Conv2D)             (None, 58, 58, 64)   4160        ['max_pooling2d_21[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_80[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 58, 58, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 58, 58, 64)   36928       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_81[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 58, 58, 64)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 58, 58, 256)  16640       ['re_lu_3[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 58, 58, 256)  16640       ['max_pooling2d_21[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 58, 58, 256)  1024       ['conv2d_82[0][0]']
#  rmalization)
#
#  batch_normalization_1 (BatchNo  (None, 58, 58, 256)  1024       ['conv2d_79[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 58, 58, 256)  0           ['batch_normalization_4[0][0]']
#
#  re_lu_1 (ReLU)                 (None, 58, 58, 256)  0           ['batch_normalization_1[0][0]']
#
#  add (Add)                      (None, 58, 58, 256)  0           ['re_lu_4[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  re_lu_5 (ReLU)                 (None, 58, 58, 256)  0           ['add[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 58, 58, 64)   16448       ['re_lu_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_83[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 58, 58, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 58, 58, 64)   36928       ['re_lu_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_84[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 58, 58, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 58, 58, 256)  16640       ['re_lu_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 58, 58, 256)  1024       ['conv2d_85[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 58, 58, 256)  0           ['batch_normalization_7[0][0]']
#
#  add_1 (Add)                    (None, 58, 58, 256)  0           ['re_lu_8[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  re_lu_9 (ReLU)                 (None, 58, 58, 256)  0           ['add_1[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 58, 58, 64)   16448       ['re_lu_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_86[0][0]']
#  rmalization)
#
#  re_lu_10 (ReLU)                (None, 58, 58, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 58, 58, 64)   36928       ['re_lu_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 58, 58, 64)  256         ['conv2d_87[0][0]']
#  rmalization)
#
#  re_lu_11 (ReLU)                (None, 58, 58, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 58, 58, 256)  16640       ['re_lu_11[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 58, 58, 256)  1024       ['conv2d_88[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 58, 58, 256)  0           ['batch_normalization_10[0][0]']
#
#  add_2 (Add)                    (None, 58, 58, 256)  0           ['re_lu_12[0][0]',
#                                                                   're_lu_9[0][0]']
#
#  re_lu_13 (ReLU)                (None, 58, 58, 256)  0           ['add_2[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 29, 29, 128)  32896       ['re_lu_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 29, 29, 128)  512        ['conv2d_90[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 29, 29, 128)  147584      ['re_lu_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 29, 29, 128)  512        ['conv2d_91[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 29, 29, 512)  66048       ['re_lu_16[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 29, 29, 512)  131584      ['re_lu_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_89[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_14[0][0]']
#
#  re_lu_14 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_11[0][0]']
#
#  add_3 (Add)                    (None, 29, 29, 512)  0           ['re_lu_17[0][0]',
#                                                                   're_lu_14[0][0]']
#
#  re_lu_18 (ReLU)                (None, 29, 29, 512)  0           ['add_3[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 29, 29, 128)  65664       ['re_lu_18[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 29, 29, 128)  512        ['conv2d_93[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 29, 29, 128)  147584      ['re_lu_19[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 29, 29, 128)  512        ['conv2d_94[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 29, 29, 512)  66048       ['re_lu_20[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_95[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_17[0][0]']
#
#  add_4 (Add)                    (None, 29, 29, 512)  0           ['re_lu_21[0][0]',
#                                                                   're_lu_18[0][0]']
#
#  re_lu_22 (ReLU)                (None, 29, 29, 512)  0           ['add_4[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 29, 29, 128)  65664       ['re_lu_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 29, 29, 128)  512        ['conv2d_96[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 29, 29, 128)  147584      ['re_lu_23[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 29, 29, 128)  512        ['conv2d_97[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 29, 29, 512)  66048       ['re_lu_24[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_98[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_20[0][0]']
#
#  add_5 (Add)                    (None, 29, 29, 512)  0           ['re_lu_25[0][0]',
#                                                                   're_lu_22[0][0]']
#
#  re_lu_26 (ReLU)                (None, 29, 29, 512)  0           ['add_5[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 29, 29, 128)  65664       ['re_lu_26[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 29, 29, 128)  512        ['conv2d_99[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 29, 29, 128)  147584      ['re_lu_27[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 29, 29, 128)  512        ['conv2d_100[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 29, 29, 512)  66048       ['re_lu_28[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_101[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_23[0][0]']
#
#  add_6 (Add)                    (None, 29, 29, 512)  0           ['re_lu_29[0][0]',
#                                                                   're_lu_26[0][0]']
#
#  re_lu_30 (ReLU)                (None, 29, 29, 512)  0           ['add_6[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 29, 29, 128)  65664       ['re_lu_30[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 29, 29, 128)  512        ['conv2d_102[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 29, 29, 128)  147584      ['re_lu_31[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 29, 29, 128)  512        ['conv2d_103[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 29, 29, 512)  66048       ['re_lu_32[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_104[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_26[0][0]']
#
#  add_7 (Add)                    (None, 29, 29, 512)  0           ['re_lu_33[0][0]',
#                                                                   're_lu_30[0][0]']
#
#  re_lu_34 (ReLU)                (None, 29, 29, 512)  0           ['add_7[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 29, 29, 128)  65664       ['re_lu_34[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 29, 29, 128)  512        ['conv2d_105[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 29, 29, 128)  147584      ['re_lu_35[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 29, 29, 128)  512        ['conv2d_106[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 29, 29, 512)  66048       ['re_lu_36[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_107[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_29[0][0]']
#
#  add_8 (Add)                    (None, 29, 29, 512)  0           ['re_lu_37[0][0]',
#                                                                   're_lu_34[0][0]']
#
#  re_lu_38 (ReLU)                (None, 29, 29, 512)  0           ['add_8[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 29, 29, 128)  65664       ['re_lu_38[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 29, 29, 128)  512        ['conv2d_108[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 29, 29, 128)  147584      ['re_lu_39[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 29, 29, 128)  512        ['conv2d_109[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 29, 29, 512)  66048       ['re_lu_40[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_110[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_32[0][0]']
#
#  add_9 (Add)                    (None, 29, 29, 512)  0           ['re_lu_41[0][0]',
#                                                                   're_lu_38[0][0]']
#
#  re_lu_42 (ReLU)                (None, 29, 29, 512)  0           ['add_9[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 29, 29, 128)  65664       ['re_lu_42[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 29, 29, 128)  512        ['conv2d_111[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 29, 29, 128)  147584      ['re_lu_43[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 29, 29, 128)  512        ['conv2d_112[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 29, 29, 512)  66048       ['re_lu_44[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 29, 29, 512)  2048       ['conv2d_113[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_35[0][0]']
#
#  add_10 (Add)                   (None, 29, 29, 512)  0           ['re_lu_45[0][0]',
#                                                                   're_lu_42[0][0]']
#
#  re_lu_46 (ReLU)                (None, 29, 29, 512)  0           ['add_10[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 15, 15, 256)  131328      ['re_lu_46[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_115[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_48[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_116[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_49[0][0]']
#                                 )
#
#  conv2d_114 (Conv2D)            (None, 15, 15, 1024  525312      ['re_lu_46[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_117[0][0]']
#  ormalization)                  )
#
#  batch_normalization_36 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_114[0][0]']
#  ormalization)                  )
#
#  re_lu_50 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  re_lu_47 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 15, 15, 1024  0           ['re_lu_50[0][0]',
#                                 )                                 're_lu_47[0][0]']
#
#  re_lu_51 (ReLU)                (None, 15, 15, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_118 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_51[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_118[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_52[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_119[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_53[0][0]']
#                                 )
#
#  batch_normalization_42 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_120[0][0]']
#  ormalization)                  )
#
#  re_lu_54 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_42[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 15, 15, 1024  0           ['re_lu_54[0][0]',
#                                 )                                 're_lu_51[0][0]']
#
#  re_lu_55 (ReLU)                (None, 15, 15, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_121 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_55[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_121[0][0]']
#  ormalization)
#
#  re_lu_56 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_56[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_122[0][0]']
#  ormalization)
#
#  re_lu_57 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_57[0][0]']
#                                 )
#
#  batch_normalization_45 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_123[0][0]']
#  ormalization)                  )
#
#  re_lu_58 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  add_13 (Add)                   (None, 15, 15, 1024  0           ['re_lu_58[0][0]',
#                                 )                                 're_lu_55[0][0]']
#
#  re_lu_59 (ReLU)                (None, 15, 15, 1024  0           ['add_13[0][0]']
#                                 )
#
#  conv2d_124 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_59[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_124[0][0]']
#  ormalization)
#
#  re_lu_60 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_60[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_125[0][0]']
#  ormalization)
#
#  re_lu_61 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_61[0][0]']
#                                 )
#
#  batch_normalization_48 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_126[0][0]']
#  ormalization)                  )
#
#  re_lu_62 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_48[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 15, 15, 1024  0           ['re_lu_62[0][0]',
#                                 )                                 're_lu_59[0][0]']
#
#  re_lu_63 (ReLU)                (None, 15, 15, 1024  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_127 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_63[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_127[0][0]']
#  ormalization)
#
#  re_lu_64 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_64[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_128[0][0]']
#  ormalization)
#
#  re_lu_65 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_65[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 15, 15, 1024  4096       ['conv2d_129[0][0]']
#  ormalization)                  )
#
#  re_lu_66 (ReLU)                (None, 15, 15, 1024  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 15, 15, 1024  0           ['re_lu_66[0][0]',
#                                 )                                 're_lu_63[0][0]']
#
#  re_lu_67 (ReLU)                (None, 15, 15, 1024  0           ['add_15[0][0]']
#                                 )
#
#  conv2d_130 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_67[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_130[0][0]']
#  ormalization)
#
#  re_lu_68 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_68[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 15, 15, 256)  1024       ['conv2d_131[0][0]']
# ...
#  re_lu_182 (ReLU)               (None, 15, 15, 1024  0           ['batch_normalization_138[0][0]']
#                                 )
#
#  add_44 (Add)                   (None, 15, 15, 1024  0           ['re_lu_182[0][0]',
#                                 )                                 're_lu_179[0][0]']
#
#  re_lu_183 (ReLU)               (None, 15, 15, 1024  0           ['add_44[0][0]']
#                                 )
#
#  conv2d_217 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_183[0][0]']
#
#  batch_normalization_139 (Batch  (None, 15, 15, 256)  1024       ['conv2d_217[0][0]']
#  Normalization)
#
#  re_lu_184 (ReLU)               (None, 15, 15, 256)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_184[0][0]']
#
#  batch_normalization_140 (Batch  (None, 15, 15, 256)  1024       ['conv2d_218[0][0]']
#  Normalization)
#
#  re_lu_185 (ReLU)               (None, 15, 15, 256)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_185[0][0]']
#                                 )
#
#  batch_normalization_141 (Batch  (None, 15, 15, 1024  4096       ['conv2d_219[0][0]']
#  Normalization)                 )
#
#  re_lu_186 (ReLU)               (None, 15, 15, 1024  0           ['batch_normalization_141[0][0]']
#                                 )
#
#  add_45 (Add)                   (None, 15, 15, 1024  0           ['re_lu_186[0][0]',
#                                 )                                 're_lu_183[0][0]']
#
#  re_lu_187 (ReLU)               (None, 15, 15, 1024  0           ['add_45[0][0]']
#                                 )
#
#  conv2d_220 (Conv2D)            (None, 15, 15, 256)  262400      ['re_lu_187[0][0]']
#
#  batch_normalization_142 (Batch  (None, 15, 15, 256)  1024       ['conv2d_220[0][0]']
#  Normalization)
#
#  re_lu_188 (ReLU)               (None, 15, 15, 256)  0           ['batch_normalization_142[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 15, 15, 256)  590080      ['re_lu_188[0][0]']
#
#  batch_normalization_143 (Batch  (None, 15, 15, 256)  1024       ['conv2d_221[0][0]']
#  Normalization)
#
#  re_lu_189 (ReLU)               (None, 15, 15, 256)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 15, 15, 1024  263168      ['re_lu_189[0][0]']
#                                 )
#
#  batch_normalization_144 (Batch  (None, 15, 15, 1024  4096       ['conv2d_222[0][0]']
#  Normalization)                 )
#
#  re_lu_190 (ReLU)               (None, 15, 15, 1024  0           ['batch_normalization_144[0][0]']
#                                 )
#
#  add_46 (Add)                   (None, 15, 15, 1024  0           ['re_lu_190[0][0]',
#                                 )                                 're_lu_187[0][0]']
#
#  re_lu_191 (ReLU)               (None, 15, 15, 1024  0           ['add_46[0][0]']
#                                 )
#
#  conv2d_224 (Conv2D)            (None, 8, 8, 512)    524800      ['re_lu_191[0][0]']
#
#  batch_normalization_146 (Batch  (None, 8, 8, 512)   2048        ['conv2d_224[0][0]']
#  Normalization)
#
#  re_lu_193 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_146[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 8, 8, 512)    2359808     ['re_lu_193[0][0]']
#
#  batch_normalization_147 (Batch  (None, 8, 8, 512)   2048        ['conv2d_225[0][0]']
#  Normalization)
#
#  re_lu_194 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_147[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 8, 8, 2048)   1050624     ['re_lu_194[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 8, 8, 2048)   2099200     ['re_lu_191[0][0]']
#
#  batch_normalization_148 (Batch  (None, 8, 8, 2048)  8192        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 8, 8, 2048)  8192        ['conv2d_223[0][0]']
#  Normalization)
#
#  re_lu_195 (ReLU)               (None, 8, 8, 2048)   0           ['batch_normalization_148[0][0]']
#
#  re_lu_192 (ReLU)               (None, 8, 8, 2048)   0           ['batch_normalization_145[0][0]']
#
#  add_47 (Add)                   (None, 8, 8, 2048)   0           ['re_lu_195[0][0]',
#                                                                   're_lu_192[0][0]']
#
#  re_lu_196 (ReLU)               (None, 8, 8, 2048)   0           ['add_47[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 8, 8, 512)    1049088     ['re_lu_196[0][0]']
#
#  batch_normalization_149 (Batch  (None, 8, 8, 512)   2048        ['conv2d_227[0][0]']
#  Normalization)
#
#  re_lu_197 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 8, 8, 512)    2359808     ['re_lu_197[0][0]']
#
#  batch_normalization_150 (Batch  (None, 8, 8, 512)   2048        ['conv2d_228[0][0]']
#  Normalization)
#
#  re_lu_198 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 8, 8, 2048)   1050624     ['re_lu_198[0][0]']
#
#  batch_normalization_151 (Batch  (None, 8, 8, 2048)  8192        ['conv2d_229[0][0]']
#  Normalization)
#
#  re_lu_199 (ReLU)               (None, 8, 8, 2048)   0           ['batch_normalization_151[0][0]']
#
#  add_48 (Add)                   (None, 8, 8, 2048)   0           ['re_lu_199[0][0]',
#                                                                   're_lu_196[0][0]']
#
#  re_lu_200 (ReLU)               (None, 8, 8, 2048)   0           ['add_48[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 8, 8, 512)    1049088     ['re_lu_200[0][0]']
#
#  batch_normalization_152 (Batch  (None, 8, 8, 512)   2048        ['conv2d_230[0][0]']
#  Normalization)
#
#  re_lu_201 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_152[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 8, 8, 512)    2359808     ['re_lu_201[0][0]']
#
#  batch_normalization_153 (Batch  (None, 8, 8, 512)   2048        ['conv2d_231[0][0]']
#  Normalization)
#
#  re_lu_202 (ReLU)               (None, 8, 8, 512)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 8, 8, 2048)   1050624     ['re_lu_202[0][0]']
#
#  batch_normalization_154 (Batch  (None, 8, 8, 2048)  8192        ['conv2d_232[0][0]']
#  Normalization)
#
#  re_lu_203 (ReLU)               (None, 8, 8, 2048)   0           ['batch_normalization_154[0][0]']
#
#  add_49 (Add)                   (None, 8, 8, 2048)   0           ['re_lu_203[0][0]',
#                                                                   're_lu_200[0][0]']
#
#  re_lu_204 (ReLU)               (None, 8, 8, 2048)   0           ['add_49[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['re_lu_204[0][0]']
#  alAveragePooling2D)
#
#  dense_8 (Dense)                (None, 200)          409800      ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 58,780,744
# Trainable params: 58,629,320
# Non-trainable params: 151,424
# __________________________________________________________________________________________________

# %% [markdown]
# ## Ensemble 기법 도입

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Add
from tensorflow.keras.models import Model

# Define Residual Network architecture
def residual_network(input_shape):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(inputs)
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    residual = x
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = Add()([x, residual])
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(10, activation='softmax')(x)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Train multiple Residual Networks
num_networks = 3
input_shape = (32, 32, 3)
num_classes = 10
epochs = 10
batch_size = 32

models = []
for i in range(num_networks):
    model = residual_network(input_shape)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(X_val, y_val))
    models.append(model)

# Make predictions
predictions = []
for model in models:
    predictions.append(model.predict(X_val))

# Combine predictions
ensemble_prediction = tf.reduce_mean(predictions, axis=0)

# Evaluate ensemble
ensemble_score = model.evaluate(X_test, y_test)

# Test ensemble
test_predictions = []
for model in models:
    test_predictions.append(model.predict(X_test))

ensemble_test_prediction = tf.reduce_mean(test_predictions, axis=0)
ensemble_test_score = model.evaluate(X_test, y_test)
