# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.layers import *
from tensorflow.keras.models import *
# Out:
# 2023-04-03 11:02:41.894210: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 11:02:42.020505: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 11:02:42.047509: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.14) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # DenseNet

# %%
def dense_block(x, blocks, growth_rate):
    for i in range(blocks):
        x = conv_block(x, growth_rate)
    return x

def conv_block(x, growth_rate):
    x1 = BatchNormalization()(x)
    x1 = Activation('relu')(x1)
    x1 = Conv2D(4 * growth_rate, (1, 1), use_bias=False, padding='same')(x1)
    x1 = BatchNormalization()(x1)
    x1 = Activation('relu')(x1)
    x1 = Conv2D(growth_rate, (3, 3), use_bias=False, padding='same')(x1)
    x = tf.keras.layers.Concatenate()([x, x1])
    return x

def transition_block(x, reduction):
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(int(tf.keras.backend.int_shape(x)[3] * reduction), (1, 1), use_bias=False, padding='same')(x)
    x = AveragePooling2D((2, 2), strides=(2, 2))(x)
    return x

def densenet(blocks=[6, 12, 64, 48], growth_rate=32, include_top=True, weights=None, input_shape=None, classes=1000):
    inputs = Input(shape=input_shape)
    x = tf.keras.layers.ZeroPadding2D(padding=((3, 3), (3, 3)))(inputs)
    x = Conv2D(64, (7, 7), strides=(2, 2), use_bias=False)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = tf.keras.layers.ZeroPadding2D(padding=((1, 1), (1, 1)))(x)
    x = MaxPooling2D((3, 3), strides=(2, 2))(x)

    for i, num_blocks in enumerate(blocks):
        x = dense_block(x, num_blocks, growth_rate)
        if i != len(blocks) - 1:
            x = transition_block(x, 0.5)

    if include_top:
        x = GlobalAveragePooling2D()(x)
        x = Dense(classes, activation='softmax')(x)
        
    model = Model(inputs, x, name='densenet')
    return model

model = densenet(input_shape=(112,112,3), classes=201)
model.summary()
# Out:
# Model: "densenet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 112, 112, 3  0           []
#                                 )]
#
#  zero_padding2d_1 (ZeroPadding2  (None, 118, 118, 3)  0          ['input_7[0][0]']
#  D)
#
#  conv2d_251 (Conv2D)            (None, 56, 56, 64)   9408        ['zero_padding2d_1[0][0]']
#
#  batch_normalization_168 (Batch  (None, 56, 56, 64)  256         ['conv2d_251[0][0]']
#  Normalization)
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['batch_normalization_168[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 64)  0           ['activation[0][0]']
#  D)
#
#  max_pooling2d_23 (MaxPooling2D  (None, 28, 28, 64)  0           ['zero_padding2d_2[0][0]']
#  )
#
#  batch_normalization_169 (Batch  (None, 28, 28, 64)  256         ['max_pooling2d_23[0][0]']
#  Normalization)
#
#  activation_1 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_169[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 28, 28, 128)  8192        ['activation_1[0][0]']
#
#  batch_normalization_170 (Batch  (None, 28, 28, 128)  512        ['conv2d_252[0][0]']
#  Normalization)
#
#  activation_2 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_170[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_2[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 96)   0           ['max_pooling2d_23[0][0]',
#                                                                   'conv2d_253[0][0]']
#
#  batch_normalization_171 (Batch  (None, 28, 28, 96)  384         ['concatenate_9[0][0]']
#  Normalization)
#
#  activation_3 (Activation)      (None, 28, 28, 96)   0           ['batch_normalization_171[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 28, 28, 128)  12288       ['activation_3[0][0]']
#
#  batch_normalization_172 (Batch  (None, 28, 28, 128)  512        ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_4 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_172[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_4[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 128)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_255[0][0]']
#
#  batch_normalization_173 (Batch  (None, 28, 28, 128)  512        ['concatenate_10[0][0]']
#  Normalization)
#
#  activation_5 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_173[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 28, 28, 128)  16384       ['activation_5[0][0]']
#
#  batch_normalization_174 (Batch  (None, 28, 28, 128)  512        ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_6 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_257 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_6[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 160)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_257[0][0]']
#
#  batch_normalization_175 (Batch  (None, 28, 28, 160)  640        ['concatenate_11[0][0]']
#  Normalization)
#
#  activation_7 (Activation)      (None, 28, 28, 160)  0           ['batch_normalization_175[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 28, 28, 128)  20480       ['activation_7[0][0]']
#
#  batch_normalization_176 (Batch  (None, 28, 28, 128)  512        ['conv2d_258[0][0]']
#  Normalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_176[0][0]']
#
#  conv2d_259 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_8[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 192)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_259[0][0]']
#
#  batch_normalization_177 (Batch  (None, 28, 28, 192)  768        ['concatenate_12[0][0]']
#  Normalization)
#
#  activation_9 (Activation)      (None, 28, 28, 192)  0           ['batch_normalization_177[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 28, 28, 128)  24576       ['activation_9[0][0]']
#
#  batch_normalization_178 (Batch  (None, 28, 28, 128)  512        ['conv2d_260[0][0]']
#  Normalization)
#
#  activation_10 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_10[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 28, 28, 224)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_261[0][0]']
#
#  batch_normalization_179 (Batch  (None, 28, 28, 224)  896        ['concatenate_13[0][0]']
#  Normalization)
#
#  activation_11 (Activation)     (None, 28, 28, 224)  0           ['batch_normalization_179[0][0]']
#
#  conv2d_262 (Conv2D)            (None, 28, 28, 128)  28672       ['activation_11[0][0]']
#
#  batch_normalization_180 (Batch  (None, 28, 28, 128)  512        ['conv2d_262[0][0]']
#  Normalization)
#
#  activation_12 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_180[0][0]']
#
#  conv2d_263 (Conv2D)            (None, 28, 28, 32)   36864       ['activation_12[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 28, 28, 256)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_263[0][0]']
#
#  batch_normalization_181 (Batch  (None, 28, 28, 256)  1024       ['concatenate_14[0][0]']
#  Normalization)
#
#  activation_13 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_181[0][0]']
#
#  conv2d_264 (Conv2D)            (None, 28, 28, 128)  32768       ['activation_13[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 128)  0          ['conv2d_264[0][0]']
#  oling2D)
#
#  batch_normalization_182 (Batch  (None, 14, 14, 128)  512        ['average_pooling2d_1[0][0]']
#  Normalization)
#
#  activation_14 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_265 (Conv2D)            (None, 14, 14, 128)  16384       ['activation_14[0][0]']
#
#  batch_normalization_183 (Batch  (None, 14, 14, 128)  512        ['conv2d_265[0][0]']
#  Normalization)
#
#  activation_15 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_266 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_15[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 14, 14, 160)  0           ['average_pooling2d_1[0][0]',
#                                                                   'conv2d_266[0][0]']
#
#  batch_normalization_184 (Batch  (None, 14, 14, 160)  640        ['concatenate_15[0][0]']
#  Normalization)
#
#  activation_16 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_184[0][0]']
#
#  conv2d_267 (Conv2D)            (None, 14, 14, 128)  20480       ['activation_16[0][0]']
#
#  batch_normalization_185 (Batch  (None, 14, 14, 128)  512        ['conv2d_267[0][0]']
#  Normalization)
#
#  activation_17 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_185[0][0]']
#
#  conv2d_268 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_17[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 14, 14, 192)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_268[0][0]']
#
#  batch_normalization_186 (Batch  (None, 14, 14, 192)  768        ['concatenate_16[0][0]']
#  Normalization)
#
#  activation_18 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_186[0][0]']
#
#  conv2d_269 (Conv2D)            (None, 14, 14, 128)  24576       ['activation_18[0][0]']
#
#  batch_normalization_187 (Batch  (None, 14, 14, 128)  512        ['conv2d_269[0][0]']
#  Normalization)
#
#  activation_19 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_187[0][0]']
#
#  conv2d_270 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 14, 14, 224)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_270[0][0]']
#
#  batch_normalization_188 (Batch  (None, 14, 14, 224)  896        ['concatenate_17[0][0]']
#  Normalization)
#
#  activation_20 (Activation)     (None, 14, 14, 224)  0           ['batch_normalization_188[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 14, 14, 128)  28672       ['activation_20[0][0]']
#
#  batch_normalization_189 (Batch  (None, 14, 14, 128)  512        ['conv2d_271[0][0]']
#  Normalization)
#
#  activation_21 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_189[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_21[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 256)  0           ['concatenate_17[0][0]',
#                                                                   'conv2d_272[0][0]']
#
#  batch_normalization_190 (Batch  (None, 14, 14, 256)  1024       ['concatenate_18[0][0]']
#  Normalization)
#
#  activation_22 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_190[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 14, 14, 128)  32768       ['activation_22[0][0]']
#
#  batch_normalization_191 (Batch  (None, 14, 14, 128)  512        ['conv2d_273[0][0]']
#  Normalization)
#
#  activation_23 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_191[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_23[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 288)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_274[0][0]']
#
#  batch_normalization_192 (Batch  (None, 14, 14, 288)  1152       ['concatenate_19[0][0]']
#  Normalization)
#
#  activation_24 (Activation)     (None, 14, 14, 288)  0           ['batch_normalization_192[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 14, 14, 128)  36864       ['activation_24[0][0]']
#
#  batch_normalization_193 (Batch  (None, 14, 14, 128)  512        ['conv2d_275[0][0]']
#  Normalization)
#
#  activation_25 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_193[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_25[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 320)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_276[0][0]']
#
#  batch_normalization_194 (Batch  (None, 14, 14, 320)  1280       ['concatenate_20[0][0]']
#  Normalization)
#
#  activation_26 (Activation)     (None, 14, 14, 320)  0           ['batch_normalization_194[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 14, 14, 128)  40960       ['activation_26[0][0]']
#
#  batch_normalization_195 (Batch  (None, 14, 14, 128)  512        ['conv2d_277[0][0]']
#  Normalization)
#
#  activation_27 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_195[0][0]']
#
#  conv2d_278 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_27[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 352)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_278[0][0]']
#
#  batch_normalization_196 (Batch  (None, 14, 14, 352)  1408       ['concatenate_21[0][0]']
#  Normalization)
#
#  activation_28 (Activation)     (None, 14, 14, 352)  0           ['batch_normalization_196[0][0]']
#
#  conv2d_279 (Conv2D)            (None, 14, 14, 128)  45056       ['activation_28[0][0]']
#
#  batch_normalization_197 (Batch  (None, 14, 14, 128)  512        ['conv2d_279[0][0]']
#  Normalization)
#
#  activation_29 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_197[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_29[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 384)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_280[0][0]']
#
#  batch_normalization_198 (Batch  (None, 14, 14, 384)  1536       ['concatenate_22[0][0]']
#  Normalization)
#
#  activation_30 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_198[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 14, 14, 128)  49152       ['activation_30[0][0]']
#
#  batch_normalization_199 (Batch  (None, 14, 14, 128)  512        ['conv2d_281[0][0]']
#  Normalization)
#
#  activation_31 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_199[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_31[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 416)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_282[0][0]']
#
#  batch_normalization_200 (Batch  (None, 14, 14, 416)  1664       ['concatenate_23[0][0]']
#  Normalization)
#
#  activation_32 (Activation)     (None, 14, 14, 416)  0           ['batch_normalization_200[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 14, 14, 128)  53248       ['activation_32[0][0]']
#
#  batch_normalization_201 (Batch  (None, 14, 14, 128)  512        ['conv2d_283[0][0]']
#  Normalization)
#
#  activation_33 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_201[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_33[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 448)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_284[0][0]']
#
#  batch_normalization_202 (Batch  (None, 14, 14, 448)  1792       ['concatenate_24[0][0]']
#  Normalization)
#
#  activation_34 (Activation)     (None, 14, 14, 448)  0           ['batch_normalization_202[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 14, 14, 128)  57344       ['activation_34[0][0]']
#
#  batch_normalization_203 (Batch  (None, 14, 14, 128)  512        ['conv2d_285[0][0]']
#  Normalization)
#
#  activation_35 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_35[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 480)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_286[0][0]']
#
#  batch_normalization_204 (Batch  (None, 14, 14, 480)  1920       ['concatenate_25[0][0]']
#  Normalization)
#
#  activation_36 (Activation)     (None, 14, 14, 480)  0           ['batch_normalization_204[0][0]']
#
#  conv2d_287 (Conv2D)            (None, 14, 14, 128)  61440       ['activation_36[0][0]']
#
#  batch_normalization_205 (Batch  (None, 14, 14, 128)  512        ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_37 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_205[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 14, 14, 32)   36864       ['activation_37[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 14, 14, 512)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_288[0][0]']
#
#  batch_normalization_206 (Batch  (None, 14, 14, 512)  2048       ['concatenate_26[0][0]']
#  Normalization)
#
#  activation_38 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_206[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 14, 14, 256)  131072      ['activation_38[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 256)   0           ['conv2d_289[0][0]']
#  oling2D)
#
#  batch_normalization_207 (Batch  (None, 7, 7, 256)   1024        ['average_pooling2d_2[0][0]']
#  Normalization)
#
#  activation_39 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_207[0][0]']
#
#  conv2d_290 (Conv2D)            (None, 7, 7, 128)    32768       ['activation_39[0][0]']
#
#  batch_normalization_208 (Batch  (None, 7, 7, 128)   512         ['conv2d_290[0][0]']
#  Normalization)
#
#  activation_40 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_208[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_40[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 7, 7, 288)    0           ['average_pooling2d_2[0][0]',
#                                                                   'conv2d_291[0][0]']
#
#  batch_normalization_209 (Batch  (None, 7, 7, 288)   1152        ['concatenate_27[0][0]']
#  Normalization)
#
#  activation_41 (Activation)     (None, 7, 7, 288)    0           ['batch_normalization_209[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 7, 7, 128)    36864       ['activation_41[0][0]']
#
#  batch_normalization_210 (Batch  (None, 7, 7, 128)   512         ['conv2d_292[0][0]']
#  Normalization)
#
#  activation_42 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_210[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_42[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 7, 7, 320)    0           ['concatenate_27[0][0]',
#                                                                   'conv2d_293[0][0]']
#
#  batch_normalization_211 (Batch  (None, 7, 7, 320)   1280        ['concatenate_28[0][0]']
#  Normalization)
#
#  activation_43 (Activation)     (None, 7, 7, 320)    0           ['batch_normalization_211[0][0]']
#
#  conv2d_294 (Conv2D)            (None, 7, 7, 128)    40960       ['activation_43[0][0]']
#
#  batch_normalization_212 (Batch  (None, 7, 7, 128)   512         ['conv2d_294[0][0]']
#  Normalization)
#
#  activation_44 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_212[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_44[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 7, 7, 352)    0           ['concatenate_28[0][0]',
#                                                                   'conv2d_295[0][0]']
#
#  batch_normalization_213 (Batch  (None, 7, 7, 352)   1408        ['concatenate_29[0][0]']
#  Normalization)
#
#  activation_45 (Activation)     (None, 7, 7, 352)    0           ['batch_normalization_213[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 7, 7, 128)    45056       ['activation_45[0][0]']
#
#  batch_normalization_214 (Batch  (None, 7, 7, 128)   512         ['conv2d_296[0][0]']
#  Normalization)
#
#  activation_46 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_214[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_46[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 7, 7, 384)    0           ['concatenate_29[0][0]',
#                                                                   'conv2d_297[0][0]']
#
#  batch_normalization_215 (Batch  (None, 7, 7, 384)   1536        ['concatenate_30[0][0]']
#  Normalization)
#
#  activation_47 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_215[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 7, 7, 128)    49152       ['activation_47[0][0]']
#
#  batch_normalization_216 (Batch  (None, 7, 7, 128)   512         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_48 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_216[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_48[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 7, 7, 416)    0           ['concatenate_30[0][0]',
#                                                                   'conv2d_299[0][0]']
#
#  batch_normalization_217 (Batch  (None, 7, 7, 416)   1664        ['concatenate_31[0][0]']
#  Normalization)
#
#  activation_49 (Activation)     (None, 7, 7, 416)    0           ['batch_normalization_217[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 7, 7, 128)    53248       ['activation_49[0][0]']
#
#  batch_normalization_218 (Batch  (None, 7, 7, 128)   512         ['conv2d_300[0][0]']
#  Normalization)
#
#  activation_50 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_218[0][0]']
#
#  conv2d_301 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_50[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 7, 7, 448)    0           ['concatenate_31[0][0]',
#                                                                   'conv2d_301[0][0]']
#
#  batch_normalization_219 (Batch  (None, 7, 7, 448)   1792        ['concatenate_32[0][0]']
#  Normalization)
#
#  activation_51 (Activation)     (None, 7, 7, 448)    0           ['batch_normalization_219[0][0]']
#
#  conv2d_302 (Conv2D)            (None, 7, 7, 128)    57344       ['activation_51[0][0]']
#
#  batch_normalization_220 (Batch  (None, 7, 7, 128)   512         ['conv2d_302[0][0]']
#  Normalization)
#
#  activation_52 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_220[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_52[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 7, 7, 480)    0           ['concatenate_32[0][0]',
#                                                                   'conv2d_303[0][0]']
#
#  batch_normalization_221 (Batch  (None, 7, 7, 480)   1920        ['concatenate_33[0][0]']
#  Normalization)
#
#  activation_53 (Activation)     (None, 7, 7, 480)    0           ['batch_normalization_221[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 7, 7, 128)    61440       ['activation_53[0][0]']
#
#  batch_normalization_222 (Batch  (None, 7, 7, 128)   512         ['conv2d_304[0][0]']
#  Normalization)
#
#  activation_54 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_222[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 7, 7, 32)     36864       ['activation_54[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 7, 7, 512)    0           ['concatenate_33[0][0]',
#                                                                   'conv2d_305[0][0]']
#
# ...
#  Normalization)
#
#  activation_246 (Activation)    (None, 3, 3, 2400)   0           ['batch_normalization_414[0][0]']
#
#  conv2d_497 (Conv2D)            (None, 3, 3, 128)    307200      ['activation_246[0][0]']
#
#  batch_normalization_415 (Batch  (None, 3, 3, 128)   512         ['conv2d_497[0][0]']
#  Normalization)
#
#  activation_247 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_415[0][0]']
#
#  conv2d_498 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_247[0][0]']
#
#  concatenate_130 (Concatenate)  (None, 3, 3, 2432)   0           ['concatenate_129[0][0]',
#                                                                   'conv2d_498[0][0]']
#
#  batch_normalization_416 (Batch  (None, 3, 3, 2432)  9728        ['concatenate_130[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 3, 3, 2432)   0           ['batch_normalization_416[0][0]']
#
#  conv2d_499 (Conv2D)            (None, 3, 3, 128)    311296      ['activation_248[0][0]']
#
#  batch_normalization_417 (Batch  (None, 3, 3, 128)   512         ['conv2d_499[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_417[0][0]']
#
#  conv2d_500 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_249[0][0]']
#
#  concatenate_131 (Concatenate)  (None, 3, 3, 2464)   0           ['concatenate_130[0][0]',
#                                                                   'conv2d_500[0][0]']
#
#  batch_normalization_418 (Batch  (None, 3, 3, 2464)  9856        ['concatenate_131[0][0]']
#  Normalization)
#
#  activation_250 (Activation)    (None, 3, 3, 2464)   0           ['batch_normalization_418[0][0]']
#
#  conv2d_501 (Conv2D)            (None, 3, 3, 128)    315392      ['activation_250[0][0]']
#
#  batch_normalization_419 (Batch  (None, 3, 3, 128)   512         ['conv2d_501[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_419[0][0]']
#
#  conv2d_502 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_251[0][0]']
#
#  concatenate_132 (Concatenate)  (None, 3, 3, 2496)   0           ['concatenate_131[0][0]',
#                                                                   'conv2d_502[0][0]']
#
#  batch_normalization_420 (Batch  (None, 3, 3, 2496)  9984        ['concatenate_132[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 3, 3, 2496)   0           ['batch_normalization_420[0][0]']
#
#  conv2d_503 (Conv2D)            (None, 3, 3, 128)    319488      ['activation_252[0][0]']
#
#  batch_normalization_421 (Batch  (None, 3, 3, 128)   512         ['conv2d_503[0][0]']
#  Normalization)
#
#  activation_253 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_421[0][0]']
#
#  conv2d_504 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_253[0][0]']
#
#  concatenate_133 (Concatenate)  (None, 3, 3, 2528)   0           ['concatenate_132[0][0]',
#                                                                   'conv2d_504[0][0]']
#
#  batch_normalization_422 (Batch  (None, 3, 3, 2528)  10112       ['concatenate_133[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 3, 3, 2528)   0           ['batch_normalization_422[0][0]']
#
#  conv2d_505 (Conv2D)            (None, 3, 3, 128)    323584      ['activation_254[0][0]']
#
#  batch_normalization_423 (Batch  (None, 3, 3, 128)   512         ['conv2d_505[0][0]']
#  Normalization)
#
#  activation_255 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_423[0][0]']
#
#  conv2d_506 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_255[0][0]']
#
#  concatenate_134 (Concatenate)  (None, 3, 3, 2560)   0           ['concatenate_133[0][0]',
#                                                                   'conv2d_506[0][0]']
#
#  batch_normalization_424 (Batch  (None, 3, 3, 2560)  10240       ['concatenate_134[0][0]']
#  Normalization)
#
#  activation_256 (Activation)    (None, 3, 3, 2560)   0           ['batch_normalization_424[0][0]']
#
#  conv2d_507 (Conv2D)            (None, 3, 3, 128)    327680      ['activation_256[0][0]']
#
#  batch_normalization_425 (Batch  (None, 3, 3, 128)   512         ['conv2d_507[0][0]']
#  Normalization)
#
#  activation_257 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_425[0][0]']
#
#  conv2d_508 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_257[0][0]']
#
#  concatenate_135 (Concatenate)  (None, 3, 3, 2592)   0           ['concatenate_134[0][0]',
#                                                                   'conv2d_508[0][0]']
#
#  batch_normalization_426 (Batch  (None, 3, 3, 2592)  10368       ['concatenate_135[0][0]']
#  Normalization)
#
#  activation_258 (Activation)    (None, 3, 3, 2592)   0           ['batch_normalization_426[0][0]']
#
#  conv2d_509 (Conv2D)            (None, 3, 3, 128)    331776      ['activation_258[0][0]']
#
#  batch_normalization_427 (Batch  (None, 3, 3, 128)   512         ['conv2d_509[0][0]']
#  Normalization)
#
#  activation_259 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_427[0][0]']
#
#  conv2d_510 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_259[0][0]']
#
#  concatenate_136 (Concatenate)  (None, 3, 3, 2624)   0           ['concatenate_135[0][0]',
#                                                                   'conv2d_510[0][0]']
#
#  batch_normalization_428 (Batch  (None, 3, 3, 2624)  10496       ['concatenate_136[0][0]']
#  Normalization)
#
#  activation_260 (Activation)    (None, 3, 3, 2624)   0           ['batch_normalization_428[0][0]']
#
#  conv2d_511 (Conv2D)            (None, 3, 3, 128)    335872      ['activation_260[0][0]']
#
#  batch_normalization_429 (Batch  (None, 3, 3, 128)   512         ['conv2d_511[0][0]']
#  Normalization)
#
#  activation_261 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_429[0][0]']
#
#  conv2d_512 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_261[0][0]']
#
#  concatenate_137 (Concatenate)  (None, 3, 3, 2656)   0           ['concatenate_136[0][0]',
#                                                                   'conv2d_512[0][0]']
#
#  batch_normalization_430 (Batch  (None, 3, 3, 2656)  10624       ['concatenate_137[0][0]']
#  Normalization)
#
#  activation_262 (Activation)    (None, 3, 3, 2656)   0           ['batch_normalization_430[0][0]']
#
#  conv2d_513 (Conv2D)            (None, 3, 3, 128)    339968      ['activation_262[0][0]']
#
#  batch_normalization_431 (Batch  (None, 3, 3, 128)   512         ['conv2d_513[0][0]']
#  Normalization)
#
#  activation_263 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_431[0][0]']
#
#  conv2d_514 (Conv2D)            (None, 3, 3, 32)     36864       ['activation_263[0][0]']
#
#  concatenate_138 (Concatenate)  (None, 3, 3, 2688)   0           ['concatenate_137[0][0]',
#                                                                   'conv2d_514[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 2688)        0           ['concatenate_138[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 201)          540489      ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 31,576,969
# Trainable params: 31,183,817
# Non-trainable params: 393,152
# __________________________________________________________________________________________________
